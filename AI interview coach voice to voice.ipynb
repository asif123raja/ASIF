# %% [markdown]
# <a href="https://colab.research.google.com/github/asif123raja/ASIF/blob/main/AI%20interview%20coach%20voice%20to%20voice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...

# %%
import whisper

model = whisper.load_model("base")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:02<00:00, 57.6MiB/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
from IPython.display import Audio
Audio("/content/abcd.opus")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
Audio("/content/bangla.opus")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("/content/bangla.opus")
audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")

# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# print the recognized text
print(result.text)
# Out:
# Detected language: bn
# mouis par model ke bhala bha be bhanala haşao transcript ko tpare sama jamu nofay kintu ikhana diksi sabki chubhala bha jo transcript ko tpale na moonha eta ami agate ke boonha moonha

# %%
! pip install gradio -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 MB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 117.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.6 MB/s eta 0:00:00

# %%
pip install gtts pydub

# %%
import whisper
from gtts import gTTS
import os
from pydub import AudioSegment
from pydub.playback import play
import google.generativeai as genai

# Set up Gemini API key
GEMINI_API_KEY = "AIzaSyDWeqcfpDwo8CSa6LJDtXNy3RTLERqOK8g"
genai.configure(api_key=GEMINI_API_KEY)

def transcribe3(audio):
    # Load audio and process
    model = whisper.load_model("base")
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # Make log-Mel spectrogram and move to model device
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # Detect spoken language
    _, probs = model.detect_language(mel)
    detected_lang = max(probs, key=probs.get)
    print(f"Detected language: {detected_lang}")

    # Decode audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    user_text = result.text
    print(f"Transcribed text: {user_text}")

    # Send transcribed text to Gemini API (as an AI interview coach)
    prompt = f"""You are an AI Interview Coach. The user has said: "{user_text}"
    Provide a constructive interview response with tips for improvement."""

    response = genai.generate_text(prompt=prompt)
    ai_response = response.result  # Extract AI-generated text
    print(f"AI Response: {ai_response}")

    # Convert AI Response to speech
    tts = gTTS(ai_response, lang=detected_lang)
    output_audio_path = "ai_response.mp3"
    tts.save(output_audio_path)

    # Play the AI-generated response
    audio = AudioSegment.from_file(output_audio_path, format="mp3")
    play(audio)

    return ai_response, output_audio_path  # Returns text + voice response

# %%
import whisper
from gtts import gTTS
import os
from pydub import AudioSegment
from pydub.playback import play

def transcribe2(audio):
    # Load audio and process
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # Make log-Mel spectrogram and move to model device
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # Detect spoken language
    _, probs = model.detect_language(mel)
    detected_lang = max(probs, key=probs.get)
    print(f"Detected language: {detected_lang}")

    # Decode audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    text = result.text

    # Convert text to speech
    tts = gTTS(text, lang=detected_lang)
    tts.save("output.mp3")

    # Play the audio
    audio = AudioSegment.from_file("output.mp3", format="mp3")
    play(audio)

    return text, "output.mp3"  # Returns both text and the saved audio file

# %%
import gradio as gr
import time

# %%
def transcribe(audio):

    #time.sleep(3)
    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)
    print(f"Detected language: {max(probs, key=probs.get)}")

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    return result.text

# %%
gr.Interface(
    title = 'OpenAI Whisper ASR Gradio Web UI',
    fn=transcribe,
    inputs=[
        gr.Audio( type="filepath")
    ],
    outputs=[
        "textbox"
    ],
    live=True).launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://9c6a11d5aace51d73b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9c6a11d5aace51d73b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
gr.Interface(
    title="OpenAI Whisper ASR Gradio Web UI",
    fn=transcribe2,
    inputs=[
        gr.Audio(type="filepath")  # Accepts audio file input
    ],
    outputs=[
        "textbox",  # Output transcribed text
        gr.Audio(type="filepath")  # Output audio file for playback
    ],
    live=True
).launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://2f5062bb703e98b725.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2f5062bb703e98b725.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import google.generativeai as genai
import gradio as gr

# Configure Gemini API
GEMINI_API_KEY = "AIzaSyArqiA2TWVRqxui5uxZ8cOKVXvycYbTyyA"
genai.configure(api_key=GEMINI_API_KEY)

def ai_interview_coach(question):
    """
    This function takes a text question as input and returns an AI-generated response
    using the Google Gemini API. The AI acts as an Interview Coach.
    """
    prompt = f"""You are an AI Interview Coach. The user has asked: "{question}"
    Provide a detailed and constructive response as if you are coaching them for a real interview."""

    try:
        # Updated line: Using generate_content instead of generate_text
        response = genai.generate_content(prompt=prompt)
        ai_response = response.text  # Extract AI-generated text
        return ai_response

    except Exception as e:
        return f"Error: {str(e)}"

# Create Gradio UI
gr.Interface(
    fn=ai_interview_coach,
    inputs=gr.Textbox(lines=2, placeholder="Ask an interview question..."),
    outputs="text",
    title="AI Interview Coach",
    description="Enter an interview question, and get a professional AI response!",
    theme="compact"
).launch()
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/blocks.py:1115: UserWarning: Cannot load compact. Caught Exception: 404 Client Error: Not Found for url: https://huggingface.co/api/spaces/compact (Request ID: Root=1-67eff97c-07e9813f5e803a31343100e4;d6726d9b-f175-4612-a850-632ff02b2f5d)
#
# Sorry, we can't find the page you are looking for.
#   warnings.warn(f"Cannot load {theme}. Caught Exception: {str(e)}")
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://7bac89a3e08d706766.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...
