# %% [markdown]
# <a href="https://colab.research.google.com/github/asif123raja/ASIF/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("Data.csv")
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
def namer(x):
    return "codemy: " + x
print(data[["Country","Purchased"]].apply(namer))
data
# Out:
#            Country    Purchased
# 0   codemy: France   codemy: No
# 1    codemy: Spain  codemy: Yes
# 2  codemy: Germany   codemy: No
# 3    codemy: Spain   codemy: No
# 4  codemy: Germany  codemy: Yes
# 5   codemy: France  codemy: Yes
# 6    codemy: Spain   codemy: No
# 7   codemy: France  codemy: Yes
# 8  codemy: Germany   codemy: No
# 9   codemy: France  codemy: Yes
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#sorting and ordering data
